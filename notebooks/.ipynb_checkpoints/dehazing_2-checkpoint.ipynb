# %%
# !git clone https://github.com/dev-hack95/haze_remover
# Out:
# Cloning into 'haze_remover'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 36 (delta 2), reused 2 (delta 0), pack-reused 27
# Receiving objects: 100% (36/36), 44.47 MiB | 17.06 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !pwd
# Out:
# /content

# %%
# !unzip haze_remover/data/dehaze.zip
# Out:
# Archive:  haze_remover/data/dehaze.zip
#   inflating: test/.DS_Store
#   inflating: test/input/32-inputs.png
#   inflating: test/input/1-inputs.png
#   inflating: test/input/24-inputs.png
#   inflating: test/input/28-inputs.png
#   inflating: test/input/31-inputs.png
#   inflating: test/input/25-inputs.png
#   inflating: test/input/23-inputs.png
#   inflating: test/input/34-inputs.png
#   inflating: test/input/7-inputs.png
#   inflating: test/input/20-inputs.png
#   inflating: test/input/9-inputs.png
#   inflating: test/input/39-inputs.png
#   inflating: test/input/30-inputs.png
#   inflating: test/input/26-inputs.png
#   inflating: test/input/21-inputs.png
#   inflating: test/input/19-inputs.png
#   inflating: test/input/4-inputs.png
#   inflating: test/input/37-inputs.png
#   inflating: test/input/45-inputs.png
#   inflating: test/input/40-inputs.png
#   inflating: test/input/15-inputs.png
#   inflating: test/input/12-inputs.png
#   inflating: test/input/44-inputs.png
# ...

# %%
import os
import time
import glob
import random
from PIL import Image
import numpy as np
import tensorflow as tf

# %%
def load_image(img_path):
    try:
        img = tf.io.read_file(str(img_path))
        img = tf.io.decode_png(img, channels=3, dtype=tf.dtypes.uint8)
        img = tf.image.resize(img, size=(224, 224), antialias=True)
        img = tf.cast(img, dtype=tf.float32) / 255.0
        print(f"Loaded image: {img_path}")
        return img, img_path
    except Exception as e:
        print(f"Error loading image: {img_path} - {e}")
        return None, None

# %%
def data_path(gt_images_path, hazy_images_path):

    gt_image_paths = list(glob.glob(gt_images_path + '*.png'))
    hazy_image_paths = list(glob.glob(hazy_images_path + "*.png"))

    train_img = []
    val_img = []

    for gt_image in gt_image_paths:
      for hazy_image in hazy_image_paths:
        train_img.append(hazy_image)
        val_img.append(hazy_image)

    total_images = len(train_img)

    temp = list(zip(train_img, val_img))
    np.random.shuffle(temp)
    train_img, val_img = zip(*temp)

    train_img = list(train_img)
    val_img = list(val_img)


    train_gt = train_img[: int(total_images * 0.6)]
    train_hazy = val_img[: int(total_images * 0.6)]
    val_gt = train_img[int(total_images * 0.6) : ]
    val_hazy = val_img[int(total_images * 0.6) : ]

    return train_img, val_img

# %%
def dataLoder(train_data, val_data, batch_size):
    train_data_img_paths = [img for img in train_data]
    train_data_hazy_paths = [img for img in train_data]
    val_data_img_paths = [img for img in val_data]
    val_data_hazy_paths = [img for img in val_data]

    print("Train data image paths:")
    print(train_data_img_paths)
    print("Train data hazy paths:")
    print(train_data_hazy_paths)
    print("Val data image paths:")
    print(val_data_img_paths)
    print("Val data hazy paths:")
    print(val_data_hazy_paths)

    train_data_img = tf.data.Dataset.from_tensor_slices(train_data_img_paths).map(load_image)
    train_data_hazy = tf.data.Dataset.from_tensor_slices(train_data_hazy_paths).map(load_image)
    train = tf.data.Dataset.zip((train_data_img, train_data_hazy)).shuffle(buffer_size=10, reshuffle_each_iteration=True).batch(batch_size)

    val_data_img = tf.data.Dataset.from_tensor_slices(val_data_img_paths).map(load_image)
    val_data_hazy = tf.data.Dataset.from_tensor_slices(val_data_hazy_paths).map(load_image)
    val = tf.data.Dataset.zip((val_data_img, val_data_hazy)).shuffle(buffer_size=10, reshuffle_each_iteration=True).batch(batch_size)

    return train, val

# %%
def load_image(img_path):
    try:
        img = tf.io.read_file(img_path)
        img = tf.io.decode_png(img, channels=3, dtype=tf.dtypes.uint8)  # Assuming RGB images
        img = tf.image.resize(img, size=(224, 224), antialias=True)
        img = tf.cast(img, dtype=tf.float32) / 255.0
        return img
    except tf.errors.NotFoundError:
        print(f"Error loading image: {img_path}")
        return None

# Function to create train and validation datasets
def data_loader(train_data, val_data, batch_size):
    train_data_img = tf.data.Dataset.from_tensor_slices(train_data).map(load_image).filter(lambda x: x is not None)
    train_data_hazy = tf.data.Dataset.from_tensor_slices(val_data).map(load_image).filter(lambda x: x is not None)
    train = tf.data.Dataset.zip((train_data_img, train_data_hazy)).batch(batch_size)

    val_data_img = tf.data.Dataset.from_tensor_slices(train_data).map(load_image).filter(lambda x: x is not None)
    val_data_hazy = tf.data.Dataset.from_tensor_slices(val_data).map(load_image).filter(lambda x: x is not None)
    val = tf.data.Dataset.zip((val_data_img, val_data_hazy)).batch(batch_size)

    return train, val

# %%
def create_model():
    inputs = tf.keras.Input(shape=[224, 224, 3])

    conv = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(inputs)
    conv = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv)

    conv_up = tf.keras.layers.Conv2D(128, 3, 2, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv)
    conv_up = tf.keras.layers.Conv2D(128, 3, 2, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv_up)

    conv1_1 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv_up)
    conv1_2 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv1_1)
    conv1_3 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),bias_initializer = b_init, kernel_regularizer = regularizer)(conv1_2)
    conc1 = tf.add(conv1_3, conv1_1)
    conv1 = tf.keras.activations.relu(conc1)

    conv2_1 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu', bias_initializer = b_init, kernel_regularizer = regularizer)(conv1)
    conv2_2 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv2_1)
    conv2_3 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),bias_initializer = b_init, kernel_regularizer = regularizer)(conv2_2)
    conc2 = tf.add(conv2_3, conv2_1)
    conv2 = tf.keras.activations.relu(conc2)

    conv3_1 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv2)
    conv3_2 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv3_1)
    conv3_3 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv3_2)
    conv3_4 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv3_3)
    conv3_5 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),bias_initializer = b_init, kernel_regularizer = regularizer)(conv3_4)
    conc3 = tf.add(conv3_5, conv3_1)
    conv3 = tf.keras.activations.relu(conc3)

    conv4_1 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv3)
    conv4_2 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv4_1)
    conv4_3 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv4_2)
    conv4_4 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(conv4_3)
    conv4_5 = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),bias_initializer = b_init, kernel_regularizer = regularizer)(conv4_4)
    conc4 = tf.add(conv4_5, conv4_1)
    conv4 = tf.keras.activations.relu(conc4)

    deconv = tf.keras.layers.Conv2DTranspose(64, 3, 2, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),kernel_regularizer = regularizer)(conv4)
    deconv = tf.keras.layers.Conv2DTranspose(64, 3, 2, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),kernel_regularizer = regularizer)(deconv)

    conv = tf.keras.layers.Conv2D(64, 3, 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',bias_initializer = b_init, kernel_regularizer = regularizer)(deconv)
    conv = tf.keras.layers.Conv2D(3, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),bias_initializer = b_init, kernel_regularizer = regularizer)(conv)
    conc = tf.add(conv, inputs)
    outputs = tf.keras.activations.relu(conc)

    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 4, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(inputs)
    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 2, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(conv)
    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 2, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(conv)
    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(conv)
    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(conv)
    conv = tf.keras.layers.Conv2D(64, 3, dilation_rate = 1, padding = 'same', kernel_initializer = k_init, activation = 'relu',kernel_regularizer = regularizer)(conv)
    deconv = tf.keras.layers.Conv2DTranspose(64, 3, dilation_rate = 4, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),activation = 'relu', kernel_regularizer = regularizer)(conv)
    conv = tf.keras.layers.Conv2D(3, 3, 1, padding = 'same', kernel_initializer = tf.keras.initializers.glorot_normal(seed = 101),kernel_regularizer = regularizer)(deconv)
    conc = tf.add(conv, inputs)
    pn_output = tf.keras.activations.relu(conc)

    output = tf.add(outputs, pn_output)

    return tf.keras.models.Model(inputs = inputs, outputs = output)

# %%
epochs = 15
batch_size = 16
k_init = tf.keras.initializers.random_normal(stddev=0.008, seed = 101)
regularizer = tf.keras.regularizers.L2(0.001)
b_init = tf.constant_initializer()

train_data, val_data = data_path("../data/test/target/", "../data/test/input/")
train, val = dataLoder(train_data, val_data, batch_size)
# Out:
# Train data image paths:
# ...

# %%
input_shape = (224, 224, 3)
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)
net = create_model()

train_loss_tracker = tf.keras.metrics.MeanSquaredError(name = "train loss")
val_loss_tracker = tf.keras.metrics.MeanSquaredError(name = "val loss")

# %%
net.compile(optimizer='adam',
              loss=tf.keras.losses.mse,
              metrics=['accuracy'])

# %%
net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['conv2d_1[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 64)   73792       ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 64)   36928       ['conv2d_4[0][0]']
#
# ...

# %%
history = net.fit(
  train,
  validation_data=val,
  epochs=5
)
# Out:
# Epoch 1/5
# 127/127 [==============================] - 142s 1s/step - loss: 0.1441 - accuracy: 0.8299 - val_loss: 0.0168 - val_accuracy: 0.9748
# Epoch 2/5
# 127/127 [==============================] - 125s 979ms/step - loss: 0.0108 - accuracy: 0.9804 - val_loss: 0.0076 - val_accuracy: 0.9837
# Epoch 3/5
# 127/127 [==============================] - 161s 1s/step - loss: 0.0060 - accuracy: 0.9858 - val_loss: 0.0048 - val_accuracy: 0.9880
# Epoch 4/5
# 127/127 [==============================] - 125s 980ms/step - loss: 0.0039 - accuracy: 0.9890 - val_loss: 0.0032 - val_accuracy: 0.9974
# Epoch 5/5
# 127/127 [==============================] - 160s 1s/step - loss: 0.0027 - accuracy: 0.9920 - val_loss: 0.0023 - val_accuracy: 0.9975

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
figure(figsize=(20, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
net.save("model.h5")
net.save_weights("weights.h5")

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt


model = tf.keras.models.load_model('../artifacts/model.h5', compile=False)  

def preprocess_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Image not found or cannot be read.")
    image = cv2.resize(image, (224, 224))  
    image = image.astype(np.float32) / 255.0  
    image = np.expand_dims(image, axis=0) 
    return image

image_path = '../data/test/input/20-inputs.png'
input_image = preprocess_image(image_path)
predicted_image = model.predict(input_image)
predicted_image = np.squeeze(predicted_image, axis=0)  
predicted_image = np.clip(predicted_image, 0, 1) 
input_image = cv2.imread(image_path)  
input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)  

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(input_image)
plt.title('Input Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(predicted_image)
plt.title('Predicted Image')
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 469ms/step
